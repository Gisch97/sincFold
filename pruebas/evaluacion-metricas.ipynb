# %%
# utils
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
from sincfold.metrics import f1_strict
from sincfold.utils import dot2bp
import json
# Out:
# Traceback (most recent call last):
#
#   File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3550 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 6
#     from sincfold.metrics import f1_strict
#
#   File ~/miniconda3/envs/sincfold/lib/python3.9/site-packages/sincfold/__init__.py:13
#     from sincfold.model import sincfold
#
#   File ~/miniconda3/envs/sincfold/lib/python3.9/site-packages/sincfold/model.py:14
#     def sincfold(pretrained=False, weights=None, model=**kwargs):
#                                                        ^
# SyntaxError: invalid syntax

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import matplotlib.pyplot as plt

# # Modelo ResNet adaptado para recibir embeddings de RNA
# class ResNetRNAEmbedding(nn.Module):
#     def __init__(self):
#         super(ResNetRNAEmbedding, self).__init__()
        
#         # Suponemos que el embedding de RNA tiene una salida de tamaño (batch_size, embedding_dim, sequence_length)
#         # Añadimos capas convolucionales 1D si el embedding es un vector 1D
#         self.conv1 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
#         self.conv2 = nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
#         self.pool = nn.MaxPool1d(2)
#         # Capa fully connected para salida
#         self.fc = nn.Linear(128 * 25, 10)  # Ajustar el tamaño según la secuencia

#     def forward(self, x):
#         # x tiene forma (batch_size, embedding_dim, sequence_length)
#         x = self.pool(F.relu(self.conv1(x)))  # Activación y pooling
#         x = self.pool(F.relu(self.conv2(x)))  # Activación y pooling
#         x = x.view(-1, 128 * 25)  # Flatten, ajustar tamaño según tu secuencia
#         x = self.fc(x)
#         return x

# # Crear una instancia del modelo
# model = ResNetRNAEmbedding()

# # Función para registrar activaciones
# activations = {}

# def get_activation(name):
#     def hook(model, input, output):
#         activations[name] = output.detach()
#     return hook

# # Registrar hooks en las capas convolucionales de interés
# model.conv1.register_forward_hook(get_activation('conv1'))
# model.conv2.register_forward_hook(get_activation('conv2'))

# # Suponiendo que el embedding de RNA tiene una dimensión de 32 y longitud de secuencia de 100
# # Esto puede depender de cómo estás generando el embedding
# input_data = torch.randn(1, 32, 100)  # Simulamos un embedding con (batch_size=1, embedding_dim=32, sequence_length=100)

# # Pasar la entrada por el modelo
# output = model(input_data)

# # Visualizar las activaciones después de la primera capa convolucional 1D
# act1 = activations['conv1'].squeeze()  # Remover la dimensión de batch
# fig, axes = plt.subplots(8, 8, figsize=(12, 12))

# # Visualizamos las activaciones de los primeros 64 filtros
# for i, ax in enumerate(axes.flat):
#     if i < 64:
#         ax.imshow(act1[i].cpu().unsqueeze(0), cmap='viridis', aspect='auto')
#         ax.axis('off')
# plt.show()

# # Visualizar las activaciones después de la segunda capa convolucional 1D
# act2 = activations['conv2'].squeeze()
# fig, axes = plt.subplots(8, 8, figsize=(12, 12))

# # Visualizar las activaciones de los primeros 128 filtros
# for i, ax in enumerate(axes.flat):
#     if i < 128:
#         ax.imshow(act2[i].cpu().unsqueeze(0), cmap='viridis', aspect='auto')
#         ax.axis('off')
# plt.show()

# %%
data = pd.read_csv('../data/ArchiveII.csv', index_col='id')

# %%
data
# Out:
#                                                                                              sequence  \
# id
# 5s_Acholeplasma-laidlawii-1                         UCUGGUGACGAUAGGUAAGAUGGUUCACCUGUUCCCAUCCCGAACA...
# 5s_Acidovorax-temperans-1                           UGCCUGAUGACCAUAGCAAGUUGGUACCACUCCUUCCCAUCCCGAA...
# tmRNA_Stre.gord._TRW-29390_1-349                    GGGGUCGUUACGGAUUCGACAGGCAUUAUGAGGCAUAUUUUGCGAC...
# tRNA_tdbR00000055-Schizosaccharomyces_pombe-489...  UCCGUUGUGGUCCAACGGCUAGGAUUCGUCGCUUUCACCGACGGGA...
# srp_List.mono._U15684                               UGGGUUGAUGAGCGUGAAGCCUUCGCUCGGUUGGAUUUUUCUUCAU...
# ...                                                                                               ...
# 5s_Bacillus-cereus-6                                UGGUAAUGAUGGCAGAGAGGUCACACCCGUUCCCAUACCGAACACG...
# srp_Myco.aviu._AE016958                             GGGGACCCCGCGCACCCGACAGAGCCCGUUGACCCUUGCUGCCUUC...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3864 entries, 0 to 3863
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          3864 non-null   object
#  1   sequence    3864 non-null   object
#  2   structure   3864 non-null   object
#  3   base_pairs  3864 non-null   object
#  4   len         3864 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 151.1+ KB

# %%
data.sample(10).to_csv('../data/ArchiveII_sample.csv')

# %%
data2 = pd.read_csv('../data/ArchiveII_sample.csv')
data2
# Out:
#                                    id  \
# 0  5s_Mannheimia-succiniciproducens-3
# 1     tmRNA_Geob.meta._CP000148_1-356
# 2               5s_Nitella-flexilis-1
# 3             srp_Haem.ducr._AE017154
# 4                     RNaseP_SM-A2642
# 5              RNaseP_C.trachomatis-D
# 6                RNaseP_P.troglodytes
# 7            5s_Halococcus-morrhuae-2
# 8               5s_Palmaria-palmata-1
# 9     tmRNA_Syne.spec._AB003477_1-394
#
#                                             sequence  \
# 0  UGGCAGCGAUAGUGCAGUGGACCCACCUAAUUCCAUGCCGAACUUA...
# 1  GGGGGUGUACAGGUUUCGACGGGGAUAGGAAACUAAAGGUUGCAUG...
# 2  AUGGUACGGUCAUACCACGGCUAAUGCGCCCGAUCCCAUCCGAACU...
# 3  GGAAACCUUCUCGGUCUCUCGCAACGGUGUCUGGUUUACUCGGUCA...
# 4  GAGGAAAGUCCGGGCACUAUAGGGCGGAGUGCCAGGUAACACCUGG...
# 5  UCGGAAGAGUAAGGCAACCGCUGAAACCAGCUUUUUAAAAAAGAUG...
# 6  AUAGGGCGGAGGGAAGCUCAUCAGUGGGGCCACGAGCUGAGUGCGU...
# 7  UUAAGGCGGCCACAGCGGCGGGGCGACUCCCGUACCCAUCCCGAAC...
# 8  ACAUGCGGCCAUAGUGCAGGAACAUGCGCCGAAACCCAUCCCGAAU...
# ...

# %%
# !sincFold test ../data/ArchiveII_sample.csv
# Out:
# Load pretrained weights...
# Start test of ../data/ArchiveII_sample.csv
# 100%|█████████████████████████████████████████████| 3/3 [02:42<00:00, 54.04s/it]
# f1,f1_post,loss
# 0.944,0.950,0.005
