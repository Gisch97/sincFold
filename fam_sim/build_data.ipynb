# %%
import pandas as pd

# %%
df = pd.read_csv("../data/ArchiveII.csv")
df
# Out:
#                                                      id  \
# 0                           5s_Acholeplasma-laidlawii-1
# 1                             5s_Acidovorax-temperans-1
# 2                      tmRNA_Stre.gord._TRW-29390_1-349
# 3     tRNA_tdbR00000055-Schizosaccharomyces_pombe-48...
# 4                                 srp_List.mono._U15684
# ...                                                 ...
# 3859                               5s_Bacillus-cereus-6
# 3860                            srp_Myco.aviu._AE016958
# 3861                    tmRNA_Heli.pylo._AE001503_1-383
# 3862                             5s_Triticum-aestivum-1
# 3863                        5s_Streptomyces-violaceus-1
#
#                                                sequence  \
# 0     UCUGGUGACGAUAGGUAAGAUGGUUCACCUGUUCCCAUCCCGAACA...
# 1     UGCCUGAUGACCAUAGCAAGUUGGUACCACUCCUUCCCAUCCCGAA...
# 2     GGGGUCGUUACGGAUUCGACAGGCAUUAUGAGGCAUAUUUUGCGAC...
# 3     UCCGUUGUGGUCCAACGGCUAGGAUUCGUCGCUUUCACCGACGGGA...
# ...

# %%
df2 = pd.read_csv("../results/ArchiveII_famfold.csv")
df2.query('method == "sincFold"')
# Out:
#                                            id dataset_name  \
# 15456             grp1_a.I1.m.M.grisea.B2.ND1    ArchiveII
# 15457       grp1_a.I1.e.P.inouyei.C1.SSU.1506    ArchiveII
# 15458     grp1_a.I1.e.C.saxonicum.C1.SSU.1506    ArchiveII
# 15459  grp1_b.I1.e.M.anisopliae.3.C1.LSU.1921    ArchiveII
# 15460    grp1_a.I1.e.G.planctonica.C1.SSU.943    ArchiveII
# ...                                       ...          ...
# 19315        16s_C.reinhardtii.chloro_domain2    ArchiveII
# 19316                16s_M.polymorpha_domain4    ArchiveII
# 19317                  16s_A.fulgidus_domain3    ArchiveII
# 19318              16s_G.intestinalis_domain4    ArchiveII
# 19319                  16s_T.maritima_domain3    ArchiveII
#
#                                                  folding    method family
# 15456  [[2, 38], [4, 36], [5, 35], [9, 32], [10, 30],...  sincFold   grp1
# 15457  [[3, 403], [14, 30], [15, 29], [16, 28], [17, ...  sincFold   grp1
# ...

# %%
import os
import pandas as pd

out_path = f"data/"
# os.mkdir(out_path)

# read dataset and predefined partitions (the files are available in this repository)
dataset = pd.read_csv("data/ArchiveII_with_prob_and_motiv.csv", index_col="id")
# partitions = pd.read_csv("data/ArchiveII_splits.csv")

# %%
fams = dataset["family"].unique()
fams
# Out:
# array(['5s', 'tmRNA', 'tRNA', 'srp', 'grp1', 'RNaseP', '23s',
#        'telomerase', '16s'], dtype=object)

# %%
for f in fams:
    dataset.loc[dataset["family"] != f].to_csv(out_path + "train_" + f + ".csv")
    dataset.loc[dataset["family"] == f].to_csv(out_path + "test_" + f + ".csv")

# %%
from sincfold.dataset import SeqDataset, pad_batch
from torch.utils.data import DataLoader
import pandas as pd

# %%
df = pd.read_csv(file1)
df
# Out:
#                                       id  \
# 0                 16s_A.fulgidus_domain2
# 1                 16s_A.fulgidus_domain3
# 2               16s_A.pyrophilus_domain2
# 3               16s_A.pyrophilus_domain4
# 4                 16s_B.subtilis_domain2
# ..                                   ...
# 432  tmRNA_uncu.bact._TRW-383630-1_1-364
# 433   tmRNA_uncu.bact._TRW-72274-1_1-359
# 434   tmRNA_uncu.bact._TRW-72274-2_1-359
# 435   tmRNA_uncu.bact._TRW-80840-3_1-379
# 436    tmRNA_uncu.mari._TRW-363180_1-347
#
#                                               sequence  \
# 0    UUUAUUGGGCCUAAAGCGUCCGUAGCCGGGCUGGUAAGUCCUCCGG...
# 1    AAGGAAUUGGCGGGGGAGCACUACAACGGGUGGAGCCUGCGGUUUA...
# 2    UCACUGGGCGUAAAGCGUCCGCAGCCGGUCGGGUAAGCGGGAUGUC...
# 3    CCGCCCGUCACGCCACGGAAGUCGGUCCGGCCGGAAGUCCCCGAGC...
# 4    AUUAUUGGGCGUAAAGGGCUCGCAGGCGGUUUCUUAAGUCUGAUGU...
# ..                                                 ...
# 432  GGGGGUGACCCCGGUUUCGACGUGGGUUACAAAGCAGUGCAGGGGC...
# ...

# %%
file1 = "/home/gkulemeyer/Documents/Repos/sincFold/fam_sim/data/rnadist/dist_100/train_srp.csv"
file2 = "/home/gkulemeyer/Documents/Repos/sincFold/fam_sim/data/rnadist/dist_200/train_srp.csv"
file3 = "/home/gkulemeyer/Documents/Repos/sincFold/fam_sim/data/rnadist/dist_400/train_srp.csv"

files = [
    file1,
    file2,
    file3,
]
for train_file in files:
    data = pd.read_csv(train_file)

    batch_size = 4
    train_loader = DataLoader(
        SeqDataset(train_file, training=True),
        batch_size=batch_size,
        shuffle=True,
        num_workers=2,
        collate_fn=pad_batch,
    )
    steps = 1000
    ep = int(round(steps / len(train_loader)))
    print(f"file:{train_file}, shape: {data.shape}")
    print(
        f"steps: {steps}, lt: {len(train_loader)}, frac: {steps / len(train_loader)}, ep: {ep}"
    )
# Out:
# file:/home/gkulemeyer/Documents/Repos/sincFold/fam_sim/data/rnadist/dist_100/train_srp.csv, shape: (472, 5)
# steps: 1000, lt: 107, frac: 9.345794392523365, ep: 9
# file:/home/gkulemeyer/Documents/Repos/sincFold/fam_sim/data/rnadist/dist_200/train_srp.csv, shape: (792, 5)
# steps: 1000, lt: 179, frac: 5.58659217877095, ep: 6
# file:/home/gkulemeyer/Documents/Repos/sincFold/fam_sim/data/rnadist/dist_400/train_srp.csv, shape: (1432, 5)
# steps: 1000, lt: 323, frac: 3.0959752321981426, ep: 3

# %%
file1 = "/home/gkulemeyer/Documents/Repos/sincFold/fam_sim/data/rnadist/dist_100/train_23s.csv"
file2 = "/home/gkulemeyer/Documents/Repos/sincFold/fam_sim/data/rnadist/dist_200/train_23s.csv"
file3 = "/home/gkulemeyer/Documents/Repos/sincFold/fam_sim/data/rnadist/dist_400/train_23s.csv"

files = [
    file1,
    file2,
    file3,
]
for train_file in files:
    data = pd.read_csv(train_file)
    batch_size = 4
    train_loader = DataLoader(
        SeqDataset(train_file, training=True),
        batch_size=batch_size,
        shuffle=True,
        num_workers=2,
        collate_fn=pad_batch,
    )
    steps = 1000
    ep = int(round(steps / len(train_loader)))
    print(f"file:{train_file}, shape: {data.shape}")
    print(
        f"steps: {steps}, lt: {len(train_loader)}, frac: {steps / len(train_loader)}, ep: {ep}"
    )
# Out:
# file:/home/gkulemeyer/Documents/Repos/sincFold/fam_sim/data/rnadist/dist_100/train_23s.csv, shape: (437, 5)
# steps: 1000, lt: 99, frac: 10.1010101010101, ep: 10
# file:/home/gkulemeyer/Documents/Repos/sincFold/fam_sim/data/rnadist/dist_200/train_23s.csv, shape: (846, 5)
# steps: 1000, lt: 191, frac: 5.2356020942408374, ep: 5
# file:/home/gkulemeyer/Documents/Repos/sincFold/fam_sim/data/rnadist/dist_400/train_23s.csv, shape: (1566, 5)
# steps: 1000, lt: 353, frac: 2.8328611898016995, ep: 3
