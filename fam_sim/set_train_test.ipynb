# %%
import os

fams = ["5s", "tmRNA", "tRNA", "srp", "grp1", "RNaseP", "23s", "telomerase", "16s"]
DATA_PATH = "data/original/"
MODELS_PATH = "models/original/"
# f'sincFold -d cuda train {train_file} --valid-file working_path/valid.csv -o working_path/output/'

for fam in fams:
    train_file = f"{DATA_PATH}train_{fam}.csv"
    out_path = f"{MODELS_PATH}{fam}/"
    train = f"sincFold -d cuda train {train_file} -o {out_path}"
    print(f"Running: {train}")
    break
    os.system(train)
# Out:
# data/original/train_5s.csv
# models/original/5s.csv
# data/original/train_tmRNA.csv
# models/original/tmRNA.csv
# data/original/train_tRNA.csv
# models/original/tRNA.csv
# data/original/train_srp.csv
# models/original/srp.csv
# data/original/train_grp1.csv
# models/original/grp1.csv
# data/original/train_RNaseP.csv
# models/original/RNaseP.csv
# data/original/train_23s.csv
# models/original/23s.csv
# data/original/train_telomerase.csv
# models/original/telomerase.csv
# data/original/train_16s.csv
# models/original/16s.csv

# %%
# test = f'sincFold -d cuda test {test_path} -w {weigths_path} -o {out_path}'
# print(f"Running: {test}")
# os.system(test)
